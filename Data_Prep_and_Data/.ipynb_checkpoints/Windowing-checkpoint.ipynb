# %%
import numpy as np
import scipy.io as sio
from mne.filter import filter_data

# %%
def segment_trial_with_label(trial_data, label, sfreq=200, window_sec=4, overlap=0.5):
    """
    Segments one trial into overlapping windows and repeats the label per window.
    """
    n_channels, n_samples = trial_data.shape
    window_size = int(window_sec * sfreq)
    step_size = int(window_size * (1 - overlap))
    
    windows = []
    for start in range(0, n_samples - window_size + 1, step_size):
        end = start + window_size
        window = trial_data[:, start:end]
        windows.append(window)
    
    if len(windows) == 0:
        return None, None  # Trial too short, skip
    
    windows = np.stack(windows)
    labels = np.full(len(windows), label)
    return windows, labels

# %%
def process_subject_mat(file_path, label_list, sfreq=200, window_sec=4, overlap=0.5):
    """
    Loads trials from a .mat file and processes all trials with corresponding labels.
    
    Returns:
        all_windows: shape (total_windows, 62, window_size)
        all_labels: shape (total_windows,)
    """
    mat_data = sio.loadmat(file_path)
    all_windows = []
    all_labels = []

    filter_eeg_dict = {}
    for key in mat_data:
        if key.startswith('cz_eeg'):
            filtered = filter_data(mat_data[key], sfreq = 200, l_freq = 0.5, h_freq = 47.0)
            filter_eeg_dict[key] = filtered

    for i in range(24):
        key = f'cz_eeg{i+1}'  # 'cz_eeg1', 'cz_eeg2', ...
        if key not in filter_eeg_dict:
            print(f"[Warning] {key} not found in the .mat file, skipping.")
            continue
        trial_data = filter_eeg_dict[key]  # shape (62, N)
        label = label_list[i]
        # print(trial_data.shape)
        # print(label)

        windows, labels = segment_trial_with_label(
            trial_data=trial_data,
            label=label,
            sfreq=sfreq,
            window_sec=window_sec,
            overlap=overlap
        )

        if windows is None:
            print(f"[Info] Trial {key} is too short, skipped.")
            continue

        all_windows.append(windows)
        all_labels.append(labels)

    # Concatenate across all trials
    all_windows = np.concatenate(all_windows, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)
    return all_windows, all_labels

# %%
label_list = [1,2,3,0,2,0,0,1,0,1,2,1,1,1,2,3,2,2,3,3,0,3,0,3]
file_path = r"D:\SEED-IV\eeg_raw_data\1\1_20160518.mat"

windows, labels = process_subject_mat(
    file_path=file_path,
    label_list=label_list,
    sfreq=200,
    window_sec=4,
    overlap=0.5
)

print("Final windows shape:", windows.shape)  # (total_windows, 62, 800)
print("Final labels shape:", labels.shape)    # (total_windows,)
# Out:
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
#
# Setting up band-pass filter from 0.5 - 47 Hz
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 47.00 Hz
# - Upper transition bandwidth: 11.75 Hz (-6 dB cutoff frequency: 52.88 Hz)
# - Filter length: 1321 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s
# Final windows shape: (1687, 62, 800)
# Final labels shape: (1687,)

# %%
data = [windows, labels]
for i in data:
    if i.ndim == 3:
        np.save(r"C:\Users\Noman\Desktop\Github\CTL_Scratch\Data_in_one_go\1\1_1_Windowed_Data.npy", i)
    else:
        np.save(r"C:\Users\Noman\Desktop\Github\CTL_Scratch\Data_in_one_go\1\1_1_Windowed_Label.npy", i)
